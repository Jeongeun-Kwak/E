# %% [markdown]
# # (E14) 폐렴 진단 해보기

# %% [markdown]
# - 일시: 2021.03.02

# %% [markdown]
# # 의료영상에 대해
# ## 의료영상의 종류
# ### X-RAY
# - **전자를 물체에 충돌시킬 때 발생하는 투과력이 강한 복사선(전자기파). 방사선의 일종.**
# - **지방, 근육, 천과 같이 밀도가 낮은 것은 수월하게 통과하지만, 밀도가 높은 뼈, 금속 들은 잘 통과하지 못함.**
#
# ### CT(Computed Tomography)
# - **환자를 중심으로 X-RAY를 빠르게 회전시켜 3D 이미지를 만들어내는 영상.**
# - **환자의 3차원 이미지를 형성하여 기본 구조와 이상을 쉽게 식별하고 위치 파악이 가능.**
# - **신체의 단면을 Slice(단층 촬영 이미지)라고 하며, X-RAY보다 자세한 정보를 포함하고 있음.**
# - **높은 방사선 사용으로 암 발생 가능성 높음.**
#
# ### MRI(Magnetic Resonance Imaging, 자기 공명 영상)
# - **신체의 해부학적 과정과 생리적 과정을 보기 위해 사용하는 의료영상 기술.**
# - **MRI 스캐너는 강한 자기장을 사용하여 신체 기관 이미지를 생성. --> CT, X-RAY 보다는 안전**
#
# ### PET(Positron Emission Tomography, 양전자 단층 촬영)
# - **양전자를 방출하는 방사선 의약품을 이용하여 인체에 대한 생리화학적, 기능적 영상을 3차원으로 얻는 핵의학 영상 촬영방법.**
# - **질병 조기 파악에 효과적.**

# %% [markdown]
# # X-RAY 이미지
# ## 의료영상 자세 분류
# ![title](https://lh3.googleusercontent.com/proxy/EMuJnifzb-oh8GopVk1rkrVbWBM_-Pf5_FaPT3lcxA1eqqZ_aTNOYt9X3RDQErcNLuZb8W7m0tuPPQRGGZfE7_6LTY8pyuaGaWhbIG5EOKw5hiG9MKR88w2AIoEo7FeBKeNOx533kVfFhDeFyMCPAmKIcjW3u10wQNMwe9tVcyQ0SQ4-CDwbSY6_D2voiD24EFhNX1-WDjYSraqhLNZNZZWulpMv1odKpKNEG5Gs7BsqnAXfzaju6BmmMtZsTKOdM5hu92eXcYFHw7kGxc8lphE1HzdGNhE8_q0PL85mEkM)
#
# > **Sagittal plane : 시상면. 사람을 왼쪽과 오른쪽을 나누는 면.**
# > **Coronal plane : 관상면. 인체를 앞 뒤로 나누는 면.**
# > **Transverse plane : 횡단면(수평면). 인체를 상하로 나누는 면.**
#
# ![title](https://aiffelstaticprd.blob.core.windows.net/media/images/08.max-800x600.png)
#
# - **영상을 볼 때는 정면을 보고 있는 것으로 가정.**
#
# ## X-RAY의 특성
# - **전자기파가 몸을 통과한 결과를 이미지화 시킨 것이기에 흑백 명암으로 나옴.**
# - **뼈는 하얀색, 공기는 검은색, 지방이나 근육은 연한 회색으로 나옴.**

# %% [markdown]
# # 폐렴 진단하기
# ## 폐렴(pneumonia)이란?
# - **중증의 호흡기 감염병으로 폐에 염증이 생긴 상태.**
# - **세균을 통한 감염이 가장 많으며, 바이러스, 균류, 기타 미생물이 원인이 될 수 있음. 드물게 알레르기 반응, 자극적인 화학 물질 흡입으로 발생하기도 함.**
# - **노인, 아이, 상태가 좋지 않은 환자, 기침반사가 약한 사람등에게는 흡인성 폐렴이 발생.**
# - **세균이 원인인 경우 항생제로 치료 가능.**
#
# ## 염증이란?
# - **유해한 자극에 대한 생체반응 중 하나로 면역세포, 혈관, 염증 매개체들이 관여하는 보호 반응.**
# - **염증의 목적은 세포의 손상을 초기 단계에서 억제하고, 상처부분의 파괴된 조직, 괴사된 세포를 제거하며, 동시에 조직을 재생하는 것.**
#
# ## 폐렴 구별법
# ![title](https://aiffelstaticprd.blob.core.windows.net/media/original_images/11_l7pucvb.png)
#
# - **X-RAY 사진상, 다양한 양상의 음영(폐 부위 희미한 그림자)증가가 관찰됨.**
#
# ![title](https://aiffelstaticprd.blob.core.windows.net/media/original_images/12_e0QcAmT.png)
#
# - **정상적인 흉부 X-RAY(왼쪽)는 음영 영역이 없는 깨끗한 폐.**
# - **세균성 폐렴(가운데)은 오른쪽 상부 옆에 음영이 있음.**
# - **바이러스성 폐렴(오른쪽)은 양쪽 폐에서 폐 전반에 확산된 음영이 보임.**

# %% [markdown]
# ****

# %% [markdown]
# # Step 1. 실험환경 세팅하기

# %%
# 라이브러리 준비
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수(변경가능)
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수(변경가능)
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /home/aiffel-dj20/aiffel

# %% [markdown]
# *****

# %% [markdown]
# # Step 2. 데이터 준비하기
# - **[데이터 다운로드](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia)는 캐글에 있는 데이터를 사용.**

# %%
# 데이터 가져오기
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/val/*/*'))

all_len = len(train_filenames)+len(test_filenames)+len(val_filenames)

print("총 데이터 개수:", all_len)

print("총 데이터 대비 train 데이터 비율: ","%.2f%%" % (len(train_filenames)/all_len*100.0))
print("총 데이터 대비 test 데이터 비율: ","%.2f%%" % (len(test_filenames)/all_len*100.0))
print("총 데이터 대비 val 데이터 비율: ","%.2f%%" % (len(val_filenames)/all_len*100.0))

# 데이터 갯수 맞추기(train --> val)
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. 
# test_size에 0.2는 20%를 의미.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print("수정한 train 데이터 개수:", len(train_filenames))
print("수정한 test 데이터 개수:", len(test_filenames))
print("수정한 val 데이터 개수:", len(val_filenames))
# Out:
# 총 데이터 개수: 5856
# 총 데이터 대비 train 데이터 비율:  89.07%
# 총 데이터 대비 test 데이터 비율:  10.66%
# 총 데이터 대비 val 데이터 비율:  0.27%
# 수정한 train 데이터 개수: 4185
# 수정한 test 데이터 개수: 624
# 수정한 val 데이터 개수: 1047

# %%
# train 데이터 안의 정상 이미지와 폐염 이미지 확인
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1078
# Pneumonia images count in training set: 3107

# %%
# tf.data 인스턴스 만들기
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# train, val 데이터셋 개수 확인
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 라벨 이름 확인
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
# 라벨 데이터 만들기 함수 구현
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴.

# %%
# 이미지 사이즈 통일을 위한 이미지 사이즈 줄이기
# 이미지 데이터 타입은 float로 바꾸고 사이즈 변경
def decode_img(img):
  # 이미지를 uint8 tensor로 바꿈.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꿈.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정.
  return tf.image.resize(img, IMAGE_SIZE)

# 제목에서 라벨 값을 가져오기
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
# train, val 데이터셋 만들기
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# 이미지 리사이즈 확인 및 라벨 확인
for image, label in train_ds.take(1): # 하나의 데이터만 가져온다는 의미
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# test 데이터셋 만들기
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# augmentation 기법으로 데이터 imbalance 극복하기
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # Step 3. 데이터 시각화

# %%
# 데이터 시각화
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # Step 4. CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # Step 5. 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# ## 모델 훈련

# %%
# 모델 선언하기
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
# 모델 fit 하기
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 26s 101ms/step - loss: 0.4621 - accuracy: 0.7653 - precision: 0.9428 - recall: 0.7282 - val_loss: 0.5731 - val_accuracy: 0.7404 - val_precision: 0.7404 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.2630 - accuracy: 0.8944 - precision: 0.9686 - recall: 0.8864 - val_loss: 0.9886 - val_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.1981 - accuracy: 0.9212 - precision: 0.9763 - recall: 0.9162 - val_loss: 0.7745 - val_accuracy: 0.7490 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.2070 - accuracy: 0.9188 - precision: 0.9746 - recall: 0.9146 - val_loss: 0.1744 - val_accuracy: 0.9365 - val_precision: 0.9930 - val_recall: 0.9208
# Epoch 5/25
# ...

# %% [markdown]
# # Step 8. 결과 확인 시각화

# %%
# 결과 확인
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# 모델 평가
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 61ms/step - loss: 0.8398 - accuracy: 0.8446 - precision: 0.8097 - recall: 0.9821

# %% [markdown]
# - **정확도가 84%로 나옴. 파라미터를 조금만 만지면 될 것 같음!**

# %% [markdown]
# # Step 9. 정확도를 올리자!

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수(변경가능)
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수(변경가능)
EPOCHS = 30

print(ROOT_PATH)
# Out:
# /home/aiffel-dj20/aiffel

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/30
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0824 - accuracy: 0.9703 - precision: 0.9927 - recall: 0.9671 - val_loss: 0.1402 - val_accuracy: 0.9471 - val_precision: 0.9972 - val_recall: 0.9313
# Epoch 2/30
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1040 - accuracy: 0.9619 - precision: 0.9893 - recall: 0.9590 - val_loss: 0.0708 - val_accuracy: 0.9692 - val_precision: 0.9920 - val_recall: 0.9662
# Epoch 3/30
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1025 - accuracy: 0.9579 - precision: 0.9906 - recall: 0.9522 - val_loss: 0.1091 - val_accuracy: 0.9548 - val_precision: 0.9959 - val_recall: 0.9430
# Epoch 4/30
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0783 - accuracy: 0.9729 - precision: 0.9934 - recall: 0.9700 - val_loss: 0.0687 - val_accuracy: 0.9731 - val_precision: 0.9844 - val_recall: 0.9792
# Epoch 5/30
# ...

# %%
# 결과 확인
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# 모델 평가
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 56ms/step - loss: 0.6006 - accuracy: 0.8926 - precision: 0.8836 - recall: 0.9538

# %% [markdown]
# - **기존 모델에서 epoch를 25에서 30으로 올렸더니 정확도가 89%가 나왔음.**

# %% [markdown]
# # 루브릭 평가

# %% [markdown]
# |평가문항|상세기준|
# |:------|:-----|
# |1. 의료영상을 처리하는 CNN 기반 딥러닝 모델이 잘 구현되었다.|모델 학습이 안정적으로 수렴하는 것을 시각화를 통해 확인하였다.|
# |2. 데이터 준비, 모델구성 등의 과정의 다양한 실험이 체계적으로 수행되었다.|regularization, augmentation 등의 기법의 사용 여부에 따른 모델 성능 측정이 ablation study 형태로 체계적으로 수행되었다.|
# |3. 실습코드를 잘 개선하여 폐렴 검출 정확도가 추가로 향상되었다.|Accuracy 기준 85%에 도달하였다.|

# %% [markdown]
# - **그래프의 파란선을 보면 epoch가 25일 때나 30일 때나 안정적으로 상승함을 볼 수 있다. val 데이터에 대해서는 epoch가 25일 때는 안정적인 상승 그래프가보이지만 epoch가 30일 때는 요동치는 모습을 볼 수 있다. 하지만 정확도는 높았다.**
#
#
# - **regularization으로 모델에 배치 정규화와 드롭아웃이 사용되었다. 그리고 데이터 양이 적어 augmentation 기법을 사용하여 좌우 반전된 데이터를 데이터셋에 추가하여 사용하였다.**
#
#
# - **이 노트북 말고 다른 노트북에서는 드롭아웃이나 배치 정규화를 지워보기도 하고, class weight를 지워보기도 했다. 하지만 모두 정확도가 70%대에 머물러 있었다. 커널을 컸다 키고 이전 노트북 복사본에서 기본 모델을 돌리니 처음으로 정확도가 85%를 넘을 수 있었다.**

# %% [markdown]
# # 회고

# %% [markdown]
# **조금은 허탈한 프로젝트였다. 아침에 영석 퍼실님이 해주신 이야기가 떠올랐다. 저스틴 존슨 교수님 이야기였다. 교수님이 그런 말을 한 적이 있다고 한다. 모델에 대해서는 '영웅이 되려고 하지 말라'고 했다는 말. 내가 만든 모델에서 regularization를 추가하고 지우거나 파라미터를 죽어라 조작해도 기존에 높은 기능을 보장하는 모델들은 못 이기며, 그 모델들을 다시 쓰게 된다는 것이다.**
#
#
# **오늘이 딱 그짝이었다. 하루종일 레이어를 지웠다가 파라미터를 바꿨다가 바꿀 수 있다고 생각한 것들은 모두 바꿨는데, 나는 기본 모델을 다시 돌려서 가장 높은 정확도를 얻을 수 있었다. 조금은 허탈한 순간이었다.**
#
#
# **원래는 입력 이미지 사이즈가 문제인가 싶어서 그걸 조정하려고 하다가 실패해서 그냥 기본 모델을 돌려본 것이었는데, 정확도가 높게 나와서 놀랐다. 인생은 초콜렛 상자라더니 어떤 초콜렛이 걸릴지, 어떤 일이 일어날지는 정말 아무도 모르는 것 같다.**
#
#
# **생각보다 일찍 정확도에 도달할 수 있어서 쓸말이 별로 없다. 의료 영상에 대해서 정확도는 정말 운이구나 싶다. 의료영상에 대해서는 AI보다는 아직은 의사 선생님의 말을 신용하는 게 낫다는 생각에 도달했다.**
#
#  **(추신) 이 노트북을 저녁에 완성해두고 삭제하는 바람에 잠시 잃어버렸다. 다행히도 /.local/share/Trash/files에 들어있어서 mv로 빼올 수 있었다. 휴지통이 있어서 정말 다행이다. 정말...**
